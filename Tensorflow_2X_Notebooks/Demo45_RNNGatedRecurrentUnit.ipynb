# %% [markdown]
# # **Spit some [tensor] flow**
#
# We need to learn the intricacies of tensorflow to master deep learning
#
# `Let's get this over with`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ## Look at the following equations
#
# Well now we're going to go into the details of the implementation;
#
# ```
# x_pred_t = w0 + w1 * x_t-1 + w2 * x_t-2 + w3 * x_t-3 + w4 * x_t-4
#
# x_pred_t+1 = w0 + w1 * x_pred_t + w2 * x_t-1 + w3 * x_t-2 + w4 * x_t-3
# ```
#
# This is an autoregressive model now.
#
# ```
# x_pred_5 = w0 + w1 * x_4 + w2 * x_3 + w3 * x_2 + w4 * x_1
#
# x_pred_6 = w0 + w1 * x_pred_5 + w2 * x_4 + w3 * x_3 + w4 * x_2
#
# ```
#
# We know that the predictions at time T in an RNN depend on all the previous times. Thus, indirectly, y(t) depends on x(t), x(t-1), x(t-2),....., x(2), x(1)
#
# To optimize the weights, we must take the derivative of the equation containing the weights; however, there will be numerous W_input_to_hidden weights in the network.
#
#
# The RNN keeps nesting the older timestamps; the derivatives use multiplication and chain rule in composite functions, thus, the more older the timestamp, the more its gradient vanishes.
#
# ## So how do GRU's work?
#
# Throwback to the RNN equation:
#
# h(t) = activation(W(x,h) x(t) + W(h,h) h(t-1) + b(h))
#
# GRU's calulate two other things to calculate h(t):
#
# - update gate vector z(t)
#
# - reset gate vector r(t)
#
# z(t) = sigmoid(W(x,z) x(t) + W(h,z) h(t-1) + b(z))
#
# r(t) = sigmoid(W(x,r) x(t) + W(h,r) h(t-1) + b(r))
#
# ```
# h(t) = (1 - z(t)) * h(t-1)  +
#
#         z(t) tanh(W(x,h) x(t) + W(h,h) (r(t) * h(t-1)) + b(h))
# ```
#
# (*) ==== element wise multiplication
#
# z(t), r(t), h(t) ===== Size U
#
# ## Z(t)
#
# Should we take the new value of h(t)? or keep h(t-1)?
#
# - z(t) close to 0, take h(t-1)
#
# - z(t) close to 1, take h(t)
#
# So:
#
# ```
# h(t) = (1 - z(t)) * h(t-1)  +
#
#         z(t) tanh(W(x,h) x(t) + W(h,h) (r(t) * h(t-1)) + b(h))
# ```
#
# Becomes
#
# ```
# h(t) = (factor keep h(t-1)) * h(t-1) +
#
#        (discard h(t-1)) * RNN(x(t), h(t-1))
# ```
#
# ## R(t)
#
# Change the value of h(t-1)
#
# - r(t) close to 0, zero value h(t-1)
#
# - r(t) close to 1, keep value h(t-1)
#
#
# ## So how do LSTM's work?
#
# ### https://towardsdatascience.com/
#
# We add another state to the mix, the cell state c(t)
#
# we add three different neurons:
#
# forget neuron = f(t)
#
# This gate decides which information should be thrown away or kept. Input from h(t-1) and x(t) is passed through this gate; and it uses sigmoid to either forget (0) or remember (1) it.
#
#
# input gate neuron = i(t)
#
# We use this to update the cell state. We pass the h(t-1) and x(t) to the sigmoid function. This will decide which values will be updated in the cell state.
#
# output gate neuron = o(t)
#
# The output gate decides what the next hidden state h(t) should be. Remember that the hidden state contains information on previous inputs. The hidden state is also used for predictions.
#
# First, we pass the previous hidden state and the current input into a sigmoid function.
#
# Then we pass the newly modified cell state to the tanh function.
#
# We multiply the tanh output with the sigmoid output to decide what information the hidden state should carry.
#
# The output is the hidden state.
#
# The new cell state and the new hidden is then carried over to the next time step.
#
# ```
#
# f(t) = sigmoid ( W(x,f) x(t) + W(h, f)h(t-1) + b(f) )
#
# i(t) = sigmoid ( W(x,i) x(t) + W(h, i)h(t-1) + b(i) )
#
# o(t) = sigmoid ( W(x,o) x(t) + W(h, o)h(t-1) + b(o) )
#
#
# c(t) = f(t) * c(t-1) +
#
#        i(t) * tanh ( W(x,c) x(t) + W(h,c) h(t-1) + b(c) )
#
#
# h(t) = o(t) * tanh( c(t) )
#
# ```

# %%
from tensorflow.keras.layers import Input, Dropout, Dense, Flatten, SimpleRNN, GRU
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam, Adamax

# %% [markdown]
# ## Let's get some synthetic data

# %%
n = 1001
x = 0.1 * np.arange(1,n)
data = np.cos(x) + np.random.randn(n-1) * 0.2

# Visualising the dataset
plt.plot(x, data, color = 'red')
plt.title('X Plot')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
T = 40
D = 1
X = []
y = []
print(len(data))  
print("The last sample would be: " + str(len(data)) + " - " + str(T) + " = " + str((len(data)-T)) )
# Out:
# 1000
# The last sample would be: 1000 - 40 = 960

# %%
for i in range(len(data) - T):
  x = data[i:i+T]
  X.append(x)
  y_temp = data[i+T]
  y.append(y_temp)

# %%
# Since we need an N x T x D input
X = np.array(X).reshape(-1, T, D) 
y = np.array(y)

# %%
print(X.shape)
print(y.shape)

N, T, D = X.shape
# Out:
# (960, 40, 1)
# (960,)

# %%
i_layer = Input(shape = (T, D))
h_layer = SimpleRNN(10)(i_layer)
o_layer = Dense(1)(h_layer)
model = Model(i_layer, o_layer)
model.compile(loss = 'mse',
              optimizer = Adam(lr = 0.1))

# %%
index = -N//2
report = model.fit(X[:index], y[:index], epochs=50, validation_data=(X[index:], y[index:]))
# Out:
# Epoch 1/50
# 15/15 [==============================] - 0s 30ms/step - loss: 0.2435 - val_loss: 0.1604
# Epoch 2/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1915 - val_loss: 0.1520
# Epoch 3/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1310 - val_loss: 0.1008
# Epoch 4/50
# 15/15 [==============================] - 0s 21ms/step - loss: 0.1065 - val_loss: 0.1014
# Epoch 5/50
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0938 - val_loss: 0.0771
# Epoch 6/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0930 - val_loss: 0.1511
# Epoch 7/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1207 - val_loss: 0.1402
# Epoch 8/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1200 - val_loss: 0.0940
# Epoch 9/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1115 - val_loss: 0.1004
# Epoch 10/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0839 - val_loss: 0.0971
# Epoch 11/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0855 - val_loss: 0.0723
# Epoch 12/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0786 - val_loss: 0.0705
# Epoch 13/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0918 - val_loss: 0.1343
# Epoch 14/50
# 15/15 [==============================] - 0s 21ms/step - loss: 0.1026 - val_loss: 0.0753
# Epoch 15/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0898 - val_loss: 0.0710
# Epoch 16/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0972 - val_loss: 0.0695
# Epoch 17/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0836 - val_loss: 0.0713
# Epoch 18/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0865 - val_loss: 0.0699
# Epoch 19/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0946 - val_loss: 0.0988
# Epoch 20/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0944 - val_loss: 0.0933
# Epoch 21/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0962 - val_loss: 0.0899
# Epoch 22/50
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0822 - val_loss: 0.1085
# Epoch 23/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0832 - val_loss: 0.0736
# Epoch 24/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0751 - val_loss: 0.0675
# Epoch 25/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0861 - val_loss: 0.0793
# Epoch 26/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0982 - val_loss: 0.0715
# Epoch 27/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0872 - val_loss: 0.0807
# Epoch 28/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0857 - val_loss: 0.0728
# Epoch 29/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0802 - val_loss: 0.0798
# Epoch 30/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0744 - val_loss: 0.0678
# Epoch 31/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0730 - val_loss: 0.0919
# Epoch 32/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0795 - val_loss: 0.0766
# Epoch 33/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0806 - val_loss: 0.0867
# Epoch 34/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0895 - val_loss: 0.0790
# Epoch 35/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0874 - val_loss: 0.0830
# Epoch 36/50
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0811 - val_loss: 0.0748
# Epoch 37/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0801 - val_loss: 0.0824
# Epoch 38/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0817 - val_loss: 0.1345
# Epoch 39/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0884 - val_loss: 0.0747
# Epoch 40/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0752 - val_loss: 0.0787
# Epoch 41/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0814 - val_loss: 0.0794
# Epoch 42/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1031 - val_loss: 0.1009
# Epoch 43/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0853 - val_loss: 0.0834
# Epoch 44/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0769 - val_loss: 0.0720
# Epoch 45/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0713 - val_loss: 0.0741
# Epoch 46/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0756 - val_loss: 0.0721
# Epoch 47/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0836 - val_loss: 0.0755
# Epoch 48/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0767 - val_loss: 0.0997
# Epoch 49/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0810 - val_loss: 0.0719
# Epoch 50/50
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0761 - val_loss: 0.0746

# %%
plt.plot(report.history['loss'], label='training_loss')
plt.plot(report.history['val_loss'], label='validation_loss')
plt.legend()

# %%
y_test = y[index:]
y_pred = []

# %%
X_end = X[index]
while len(y_pred) < len(y_test):
  pred = model.predict(X_end.reshape(1, -1))[0,0]
  y_pred.append(pred)
  X_end = np.roll(X_end, -1)
  X_end[-1] = pred

# %%
print(len(y_pred))
print(len(y_test))
# Out:
# 480
# 480

# %%
plt.plot(y_test, label='y_test')
plt.plot(y_pred, label='y_pred')
plt.legend()

# %%
y_test_single = y[index:]
y_pred_single = []

i = index
while len(y_pred_single) < len(y_test_single):
  pred = model.predict(X[i].reshape(1,T, D))[0,0]
  i+=1
  y_pred_single.append(pred)

plt.plot(y_test_single, label='y_test_single')
plt.plot(y_pred_single, label='y_pred_singe')
plt.legend()

# %% [markdown]
# ## This is bad, the single prediction shows that our model just copies the previous value, this is bad bad bad
#
# But we're in too deep in the world of deep learning, we must find a way! Let's fix our window

# %%
T = 40
D = 1
X = []
y = []
print(len(data))  
print("The last sample would be: " + str(len(data)) + " - " + str(T) + " = " + str((len(data)-T)) )

for i in range(len(data) - T):
  x = data[i:i+T]
  X.append(x)
  y_temp = data[i+T]
  y.append(y_temp)

X = np.array(X).reshape(-1, T, D) 
y = np.array(y)

i_layer = Input(shape = (T, D))
h_layer = GRU(10, activation='tanh')(i_layer)
o_layer = Dense(1)(h_layer)
model = Model(i_layer, o_layer)
model.compile(loss = 'mse',
              optimizer = Adam(lr = 0.2))

index = -N//4
report = model.fit(X[:index], y[:index], epochs=50, validation_data=(X[index:], y[index:]))

plt.plot(report.history['loss'], label='training_loss')
plt.plot(report.history['val_loss'], label='validation_loss')
plt.legend()
# Out:
# 1000
# The last sample would be: 1000 - 40 = 960
# Epoch 1/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.1881 - val_loss: 0.0732
# Epoch 2/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1348 - val_loss: 0.1374
# Epoch 3/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0973 - val_loss: 0.0645
# Epoch 4/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0670 - val_loss: 0.0472
# Epoch 5/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0674 - val_loss: 0.0462
# Epoch 6/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0561 - val_loss: 0.0461
# Epoch 7/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0614 - val_loss: 0.0826
# Epoch 8/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0644 - val_loss: 0.0528
# Epoch 9/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0695 - val_loss: 0.0626
# Epoch 10/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0648 - val_loss: 0.0425
# Epoch 11/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0633 - val_loss: 0.0549
# Epoch 12/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0726 - val_loss: 0.0494
# Epoch 13/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0724 - val_loss: 0.0453
# Epoch 14/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0620 - val_loss: 0.0432
# Epoch 15/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0549 - val_loss: 0.0428
# Epoch 16/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0546 - val_loss: 0.0431
# Epoch 17/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0523 - val_loss: 0.0428
# Epoch 18/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0571 - val_loss: 0.0842
# Epoch 19/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0575 - val_loss: 0.0554
# Epoch 20/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0711 - val_loss: 0.1020
# Epoch 21/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0645 - val_loss: 0.0482
# Epoch 22/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0605 - val_loss: 0.0492
# Epoch 23/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0621 - val_loss: 0.0444
# Epoch 24/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0577 - val_loss: 0.0643
# Epoch 25/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0630 - val_loss: 0.0493
# Epoch 26/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0606 - val_loss: 0.0469
# Epoch 27/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0650 - val_loss: 0.0552
# Epoch 28/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0586 - val_loss: 0.0447
# Epoch 29/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0664 - val_loss: 0.0444
# Epoch 30/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0577 - val_loss: 0.0460
# Epoch 31/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0523 - val_loss: 0.0446
# Epoch 32/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0501 - val_loss: 0.0451
# Epoch 33/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0496 - val_loss: 0.0506
# Epoch 34/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0505 - val_loss: 0.0522
# Epoch 35/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0491 - val_loss: 0.0511
# Epoch 36/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0516 - val_loss: 0.0523
# Epoch 37/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0515 - val_loss: 0.0441
# Epoch 38/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0504 - val_loss: 0.0446
# Epoch 39/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0544 - val_loss: 0.0683
# Epoch 40/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0625 - val_loss: 0.0666
# Epoch 41/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0573 - val_loss: 0.0463
# Epoch 42/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0498 - val_loss: 0.0591
# Epoch 43/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0558 - val_loss: 0.0498
# Epoch 44/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0561 - val_loss: 0.0444
# Epoch 45/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0551 - val_loss: 0.0429
# Epoch 46/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0488 - val_loss: 0.0406
# Epoch 47/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0503 - val_loss: 0.0520
# Epoch 48/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0513 - val_loss: 0.0497
# Epoch 49/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0522 - val_loss: 0.0461
# Epoch 50/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0534 - val_loss: 0.0667

# %%
y_test = y[index:]
y_pred = []
X_end = X[index]
while len(y_pred) < len(y_test):
  pred = model.predict(X_end.reshape(1, -1))[0,0]
  y_pred.append(pred)
  X_end = np.roll(X_end, -1)
  X_end[-1] = pred
plt.plot(y_test, label='y_test')
plt.plot(y_pred, label='y_pred')
plt.legend()

# %%
y_test_single = y[index:]
y_pred_single = []

i = index
while len(y_pred_single) < len(y_test_single):
  pred = model.predict(X[i].reshape(1,T, D))[0,0]
  i+=1
  y_pred_single.append(pred)

plt.plot(y_test_single, label='y_test_single')
plt.plot(y_pred_single, label='y_pred_singe')
plt.legend()

# %%
T = 100
D = 1
X = []
y = []
print(len(data))  
print("The last sample would be: " + str(len(data)) + " - " + str(T) + " = " + str((len(data)-T)) )

for i in range(len(data) - T):
  x = data[i:i+T]
  X.append(x)
  y_temp = data[i+T]
  y.append(y_temp)

X = np.array(X).reshape(-1, T, D) 
y = np.array(y)

i_layer = Input(shape = (T, D))
h_layer = GRU(10, activation='tanh')(i_layer)
o_layer = Dense(1)(h_layer)
model = Model(i_layer, o_layer)
model.compile(loss = 'mse',
              optimizer = Adam(lr = 0.2))

index = -N//4
report = model.fit(X[:index], y[:index], epochs=50, validation_data=(X[index:], y[index:]))

plt.plot(report.history['loss'], label='training_loss')
plt.plot(report.history['val_loss'], label='validation_loss')
plt.legend()
# Out:
# 1000
# The last sample would be: 1000 - 100 = 900
# Epoch 1/50
# 21/21 [==============================] - 0s 21ms/step - loss: 0.3317 - val_loss: 0.0851
# Epoch 2/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0903 - val_loss: 0.0722
# Epoch 3/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0766 - val_loss: 0.0757
# Epoch 4/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0696 - val_loss: 0.0611
# Epoch 5/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0792 - val_loss: 0.0935
# Epoch 6/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0802 - val_loss: 0.0690
# Epoch 7/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0641 - val_loss: 0.0636
# Epoch 8/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0649 - val_loss: 0.0580
# Epoch 9/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0649 - val_loss: 0.0534
# Epoch 10/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0678 - val_loss: 0.0638
# Epoch 11/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0693 - val_loss: 0.0581
# Epoch 12/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0756 - val_loss: 0.0568
# Epoch 13/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0680 - val_loss: 0.0629
# Epoch 14/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0786 - val_loss: 0.0582
# Epoch 15/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0937 - val_loss: 0.0617
# Epoch 16/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0710 - val_loss: 0.0602
# Epoch 17/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0653 - val_loss: 0.0535
# Epoch 18/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0615 - val_loss: 0.0626
# Epoch 19/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0679 - val_loss: 0.0718
# Epoch 20/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0767 - val_loss: 0.0669
# Epoch 21/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0737 - val_loss: 0.0590
# Epoch 22/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0677 - val_loss: 0.0583
# Epoch 23/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0653 - val_loss: 0.0651
# Epoch 24/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0753 - val_loss: 0.0797
# Epoch 25/50
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0748 - val_loss: 0.0686
# Epoch 26/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0675 - val_loss: 0.0534
# Epoch 27/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0645 - val_loss: 0.0818
# Epoch 28/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0811 - val_loss: 0.0582
# Epoch 29/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0631 - val_loss: 0.0680
# Epoch 30/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0720 - val_loss: 0.0572
# Epoch 31/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0736 - val_loss: 0.0575
# Epoch 32/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0674 - val_loss: 0.0720
# Epoch 33/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0695 - val_loss: 0.0611
# Epoch 34/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0638 - val_loss: 0.0549
# Epoch 35/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0674 - val_loss: 0.0634
# Epoch 36/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0693 - val_loss: 0.0575
# Epoch 37/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0627 - val_loss: 0.0515
# Epoch 38/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0653 - val_loss: 0.0629
# Epoch 39/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0636 - val_loss: 0.0645
# Epoch 40/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0616 - val_loss: 0.0585
# Epoch 41/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0684 - val_loss: 0.0578
# Epoch 42/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0742 - val_loss: 0.0982
# Epoch 43/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0773 - val_loss: 0.0838
# Epoch 44/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0768 - val_loss: 0.0833
# Epoch 45/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0898 - val_loss: 0.0615
# Epoch 46/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0765 - val_loss: 0.0720
# Epoch 47/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0634 - val_loss: 0.0579
# Epoch 48/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0688 - val_loss: 0.0657
# Epoch 49/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0708 - val_loss: 0.0588
# Epoch 50/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0693 - val_loss: 0.0605

# %%
y_test = y[index:]
y_pred = []
X_end = X[index]
while len(y_pred) < len(y_test):
  pred = model.predict(X_end.reshape(1, -1))[0,0]
  y_pred.append(pred)
  X_end = np.roll(X_end, -1)
  X_end[-1] = pred
plt.plot(y_test, label='y_test')
plt.plot(y_pred, label='y_pred')
plt.legend()

# %%
y_test_single = y[index:]
y_pred_single = []

i = index
while len(y_pred_single) < len(y_test_single):
  pred = model.predict(X[i].reshape(1,T, D))[0,0]
  i+=1
  y_pred_single.append(pred)

plt.plot(y_test_single, label='y_test_single')
plt.plot(y_pred_single, label='y_pred_singe')
plt.legend()
