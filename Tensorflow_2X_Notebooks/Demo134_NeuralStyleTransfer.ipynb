# %% [markdown]
# # **Spit some [tensor] flow**
#
# We need to learn the intricacies of tensorflow to master deep learning
#
# Reference: https://www.tensorflow.org/tutorials

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %%
from glob import glob
import sys, os
import PIL.Image
matplotlib.rcParams['figure.figsize'] = (12,12)
matplotlib.rcParams['axes.grid'] = False

# %%
def tensor_to_image(tensor):
  tensor = tensor*255
  tensor = np.array(tensor, dtype=np.uint8)
  if np.ndim(tensor)>3:
    assert tensor.shape[0] == 1
    tensor = tensor[0]
  return PIL.Image.fromarray(tensor)

# %%
url = 'https://4.bp.blogspot.com/-0lGN2edQlMc/XlIsRH6C1rI/AAAAAAAAVT0/VCD__KkKY2UAZQPxa7rJ0YtOs6WJlsmxwCLcBGAsYHQ/w914-h514-p-k-no-nu/bts-jimin-black-wings-map-of-the-soul-7-uhdpaper.com-4K-6.682-wp.thumbnail.jpg'

# %%
style_url = 'https://cdn.britannica.com/78/43678-050-F4DC8D93/Starry-Night-canvas-Vincent-van-Gogh-New-1889.jpg'

# %%
name = url.split('/')[-1]
content_path = tf.keras.utils.get_file(name, origin=url)
name = style_url.split('/')[-1]
style_path = tf.keras.utils.get_file(name, origin=style_url)
# Out:
# Downloading data from https://4.bp.blogspot.com/-0lGN2edQlMc/XlIsRH6C1rI/AAAAAAAAVT0/VCD__KkKY2UAZQPxa7rJ0YtOs6WJlsmxwCLcBGAsYHQ/w914-h514-p-k-no-nu/bts-jimin-black-wings-map-of-the-soul-7-uhdpaper.com-4K-6.682-wp.thumbnail.jpg
# 81920/79917 [==============================] - 0s 1us/step
# Downloading data from https://cdn.britannica.com/78/43678-050-F4DC8D93/Starry-Night-canvas-Vincent-van-Gogh-New-1889.jpg
# 884736/884624 [==============================] - 0s 0us/step

# %%
def load_img(path_to_img):
  max_dim = 512
  img = tf.io.read_file(path_to_img)
  img = tf.image.decode_image(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.float32)

  shape = tf.cast(tf.shape(img)[:-1], tf.float32)
  long_dim = max(shape)
  scale = max_dim / long_dim

  new_shape = tf.cast(shape * scale, tf.int32)

  img = tf.image.resize(img, new_shape)
  img = img[tf.newaxis, :]
  return img

# %%
def imshow(image, title=None):
  if len(image.shape) > 3:
    image = tf.squeeze(image, axis=0)

  plt.imshow(image)
  if title:
    plt.title(title)

# %%
content_image = load_img(content_path)
style_image = load_img(style_path)

plt.subplot(1, 2, 1)
imshow(content_image, 'Content Image')

plt.subplot(1, 2, 2)
imshow(style_image, 'Style Image')

# %%
import tensorflow_hub as hub
hub_module = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/1')
stylized_image = hub_module(tf.constant(content_image), tf.constant(style_image))[0]
tensor_to_image(stylized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7F5BA823E400>
