# %% [markdown]
# # **Spit some [tensor] flow**
#
# We need to learn the intricacies of tensorflow to master deep learning
#
# `Let's get this over with`

# %% [markdown]
# ## Look at the following equations
#
# Well now we're going to go into the details of the implementation;
#
# ```
# x_pred_t = w0 + w1 * x_t-1 + w2 * x_t-2 + w3 * x_t-3 + w4 * x_t-4
#
# x_pred_t+1 = w0 + w1 * x_pred_t + w2 * x_t-1 + w3 * x_t-2 + w4 * x_t-3
# ```
#
# This is an autoregressive model now.
#
# ```
# x_pred_5 = w0 + w1 * x_4 + w2 * x_3 + w3 * x_2 + w4 * x_1
#
# x_pred_6 = w0 + w1 * x_pred_5 + w2 * x_4 + w3 * x_3 + w4 * x_2
#
# ```
#
# We know that the predictions at time T in an RNN depend on all the previous times. Thus, indirectly, y(t) depends on x(t), x(t-1), x(t-2),....., x(2), x(1)
#
# To optimize the weights, we must take the derivative of the equation containing the weights; however, there will be numerous W_input_to_hidden weights in the network.
#
#
# The RNN keeps nesting the older timestamps; the derivatives use multiplication and chain rule in composite functions, thus, the more older the timestamp, the more its gradient vanishes.
#
# ## So how do GRU's work?
#
# Throwback to the RNN equation:
#
# h(t) = activation(W(x,h) x(t) + W(h,h) h(t-1) + b(h))
#
# GRU's calulate two other things to calculate h(t):
#
# - update gate vector z(t)
#
# - reset gate vector r(t)
#
# z(t) = sigmoid(W(x,z) x(t) + W(h,z) h(t-1) + b(z))
#
# r(t) = sigmoid(W(x,r) x(t) + W(h,r) h(t-1) + b(r))
#
# ```
# h(t) = (1 - z(t)) * h(t-1)  +
#
#         z(t) tanh(W(x,h) x(t) + W(h,h) (r(t) * h(t-1)) + b(h))
# ```
#
# (*) ==== element wise multiplication
#
# z(t), r(t), h(t) ===== Size U
#
# ## Z(t)
#
# Should we take the new value of h(t)? or keep h(t-1)?
#
# - z(t) close to 0, take h(t-1)
#
# - z(t) close to 1, take h(t)
#
# So:
#
# ```
# h(t) = (1 - z(t)) * h(t-1)  +
#
#         z(t) tanh(W(x,h) x(t) + W(h,h) (r(t) * h(t-1)) + b(h))
# ```
#
# Becomes
#
# ```
# h(t) = (factor keep h(t-1)) * h(t-1) +
#
#        (discard h(t-1)) * RNN(x(t), h(t-1))
# ```
#
# ## R(t)
#
# Change the value of h(t-1)
#
# - r(t) close to 0, zero value h(t-1)
#
# - r(t) close to 1, keep value h(t-1)
#
#
# ## So how do LSTM's work?
#
# ### https://towardsdatascience.com/
#
# We add another state to the mix, the cell state c(t)
#
# we add three different neurons:
#
# forget neuron = f(t)
#
# This gate decides which information should be thrown away or kept. Input from h(t-1) and x(t) is passed through this gate; and it uses sigmoid to either forget (0) or remember (1) it.
#
#
# input gate neuron = i(t)
#
# We use this to update the cell state. We pass the h(t-1) and x(t) to the sigmoid function. This will decide which values will be updated in the cell state.
#
# output gate neuron = o(t)
#
# The output gate decides what the next hidden state h(t) should be. Remember that the hidden state contains information on previous inputs. The hidden state is also used for predictions.
#
# First, we pass the previous hidden state and the current input into a sigmoid function.
#
# Then we pass the newly modified cell state to the tanh function.
#
# We multiply the tanh output with the sigmoid output to decide what information the hidden state should carry.
#
# The output is the hidden state.
#
# The new cell state and the new hidden is then carried over to the next time step.
#
# ```
#
# f(t) = sigmoid ( W(x,f) x(t) + W(h, f)h(t-1) + b(f) )
#
# i(t) = sigmoid ( W(x,i) x(t) + W(h, i)h(t-1) + b(i) )
#
# o(t) = sigmoid ( W(x,o) x(t) + W(h, o)h(t-1) + b(o) )
#
#
# c(t) = f(t) * c(t-1) +
#
#        i(t) * tanh ( W(x,c) x(t) + W(h,c) h(t-1) + b(c) )
#
#
# h(t) = o(t) * tanh( c(t) )
#
# ```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
print(tf.__version__)
# Out:
# 2.2.0

# %%
from tensorflow.keras.layers import Input, Dropout, Dense, GlobalMaxPool1D, SimpleRNN, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam, Adamax

# %% [markdown]
# ## Let's get some synthetic data

# %%
n = 1001
x = 0.1 * np.arange(1,n)
data = np.cos(x) + np.random.randn(n-1) * 0.5

# Visualising the dataset
plt.plot(x, data, color = 'red')
plt.title('X Plot')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
T = 40
D = 1
X = []
y = []
print(len(data))  
print("The last sample would be: " + str(len(data)) + " - " + str(T) + " = " + str((len(data)-T)) )
# Out:
# 1000
# The last sample would be: 1000 - 40 = 960

# %%
for i in range(len(data) - T):
  x = data[i:i+T]
  X.append(x)
  y_temp = data[i+T]
  y.append(y_temp)

# %%
# Since we need an N x T x D input
X = np.array(X).reshape(-1, T, D) 
y = np.array(y)

# %%
print(X.shape)
print(y.shape)

N, T, D = X.shape
# Out:
# (960, 40, 1)
# (960,)

# %%
i_layer = Input(shape = (T, D))
h_layer = SimpleRNN(10)(i_layer)
o_layer = Dense(1)(h_layer)
model = Model(i_layer, o_layer)
model.compile(loss = 'mse',
              optimizer = Adam(lr = 0.1))

# %%
index = -N//4
report = model.fit(X[:index], y[:index], epochs=50, validation_data=(X[index:], y[index:]))
# Out:
# Epoch 1/50
# 23/23 [==============================] - 1s 32ms/step - loss: 0.4607 - val_loss: 0.4071
# Epoch 2/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4912 - val_loss: 0.4579
# Epoch 3/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4518 - val_loss: 0.7221
# Epoch 4/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4819 - val_loss: 0.3874
# Epoch 5/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4199 - val_loss: 0.3679
# Epoch 6/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.6170 - val_loss: 0.7683
# Epoch 7/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.7708 - val_loss: 0.7890
# Epoch 8/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.7877 - val_loss: 0.5092
# Epoch 9/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.5617 - val_loss: 0.4216
# Epoch 10/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4246 - val_loss: 0.4079
# Epoch 11/50
# 23/23 [==============================] - 1s 29ms/step - loss: 0.4219 - val_loss: 0.3727
# Epoch 12/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4242 - val_loss: 0.4005
# Epoch 13/50
# 23/23 [==============================] - 1s 29ms/step - loss: 0.4456 - val_loss: 0.4009
# Epoch 14/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4246 - val_loss: 0.4214
# Epoch 15/50
# 23/23 [==============================] - 1s 29ms/step - loss: 0.4511 - val_loss: 0.4248
# Epoch 16/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.4399 - val_loss: 0.4007
# Epoch 17/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.4294 - val_loss: 0.5181
# Epoch 18/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4645 - val_loss: 0.4485
# Epoch 19/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4278 - val_loss: 0.4062
# Epoch 20/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4373 - val_loss: 0.3859
# Epoch 21/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4407 - val_loss: 0.3899
# Epoch 22/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4388 - val_loss: 0.4066
# Epoch 23/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4326 - val_loss: 0.3825
# Epoch 24/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.4404 - val_loss: 0.3877
# Epoch 25/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4040 - val_loss: 0.3779
# Epoch 26/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4298 - val_loss: 0.4113
# Epoch 27/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4543 - val_loss: 0.4616
# Epoch 28/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4292 - val_loss: 0.4335
# Epoch 29/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4861 - val_loss: 0.4294
# Epoch 30/50
# 23/23 [==============================] - 1s 29ms/step - loss: 0.4348 - val_loss: 0.3936
# Epoch 31/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.4745 - val_loss: 0.3815
# Epoch 32/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.5085 - val_loss: 0.4673
# Epoch 33/50
# 23/23 [==============================] - 1s 26ms/step - loss: 0.4562 - val_loss: 0.5080
# Epoch 34/50
# 23/23 [==============================] - 1s 26ms/step - loss: 0.4421 - val_loss: 0.4259
# Epoch 35/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4279 - val_loss: 0.3752
# Epoch 36/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4540 - val_loss: 0.4402
# Epoch 37/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4315 - val_loss: 0.4180
# Epoch 38/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4534 - val_loss: 0.4062
# Epoch 39/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.4624 - val_loss: 0.4131
# Epoch 40/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.4431 - val_loss: 0.3849
# Epoch 41/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.4351 - val_loss: 0.4966
# Epoch 42/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.5084 - val_loss: 0.4292
# Epoch 43/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4454 - val_loss: 0.4277
# Epoch 44/50
# 23/23 [==============================] - 1s 29ms/step - loss: 0.4272 - val_loss: 0.4787
# Epoch 45/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4735 - val_loss: 0.4689
# Epoch 46/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4191 - val_loss: 0.3900
# Epoch 47/50
# 23/23 [==============================] - 1s 28ms/step - loss: 0.4474 - val_loss: 0.3994
# Epoch 48/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.4360 - val_loss: 0.3950
# Epoch 49/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.4928 - val_loss: 0.4653
# Epoch 50/50
# 23/23 [==============================] - 1s 27ms/step - loss: 0.4994 - val_loss: 0.4630

# %%
plt.plot(report.history['loss'], label='training_loss')
plt.plot(report.history['val_loss'], label='validation_loss')
plt.legend()

# %%
y_test = y[index:]
y_pred = []

# %%
X_end = X[index]
while len(y_pred) < len(y_test):
  pred = model.predict(X_end.reshape(1, -1))[0,0]
  y_pred.append(pred)
  X_end = np.roll(X_end, -1)
  X_end[-1] = pred

# %%
print(len(y_pred))
print(len(y_test))
# Out:
# 240
# 240

# %%
plt.plot(y_test, label='y_test')
plt.plot(y_pred, label='y_pred')
plt.legend()

# %%
y_test_single = y[index:]
y_pred_single = []

i = index
while len(y_pred_single) < len(y_test_single):
  pred = model.predict(X[i].reshape(1,T, D))[0,0]
  i+=1
  y_pred_single.append(pred)

plt.plot(y_test_single, label='y_test_single')
plt.plot(y_pred_single, label='y_pred_singe')
plt.legend()

# %% [markdown]
# ## This is bad, the single prediction shows that our model just copies the previous value, this is bad bad bad
#
# But we're in too deep in the world of deep learning, we must find a way! Let's fix our window

# %%
T = 40
D = 1
X = []
y = []
print(len(data))  
print("The last sample would be: " + str(len(data)) + " - " + str(T) + " = " + str((len(data)-T)) )

for i in range(len(data) - T):
  x = data[i:i+T]
  X.append(x)
  y_temp = data[i+T]
  y.append(y_temp)

X = np.array(X).reshape(-1, T, D) 
y = np.array(y)

i_layer = Input(shape = (T, D))
h_layer = LSTM(10, activation='tanh')(i_layer)
o_layer = Dense(1)(h_layer)
model = Model(i_layer, o_layer)
model.compile(loss = 'mse',
              optimizer = Adam(lr = 0.2))

index = -N//4
report = model.fit(X[:index], y[:index], epochs=50, validation_data=(X[index:], y[index:]))

plt.plot(report.history['loss'], label='training_loss')
plt.plot(report.history['val_loss'], label='validation_loss')
plt.legend()
# Out:
# 1000
# The last sample would be: 1000 - 40 = 960
# Epoch 1/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.6057 - val_loss: 0.3851
# Epoch 2/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4268 - val_loss: 0.3654
# Epoch 3/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3782 - val_loss: 0.3533
# Epoch 4/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3728 - val_loss: 0.3536
# Epoch 5/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3787 - val_loss: 0.3603
# Epoch 6/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4110 - val_loss: 0.3809
# Epoch 7/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3875 - val_loss: 0.3775
# Epoch 8/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3730 - val_loss: 0.3389
# Epoch 9/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3769 - val_loss: 0.4237
# Epoch 10/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4100 - val_loss: 0.3483
# Epoch 11/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3711 - val_loss: 0.3539
# Epoch 12/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3523 - val_loss: 0.3646
# Epoch 13/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3922 - val_loss: 0.3702
# Epoch 14/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3535 - val_loss: 0.3147
# Epoch 15/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3503 - val_loss: 0.3449
# Epoch 16/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3533 - val_loss: 0.3269
# Epoch 17/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3392 - val_loss: 0.2972
# Epoch 18/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3476 - val_loss: 0.4126
# Epoch 19/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3822 - val_loss: 0.3509
# Epoch 20/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3558 - val_loss: 0.3741
# Epoch 21/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3789 - val_loss: 0.3205
# Epoch 22/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3446 - val_loss: 0.3132
# Epoch 23/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3577 - val_loss: 0.3398
# Epoch 24/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3862 - val_loss: 0.3770
# Epoch 25/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3821 - val_loss: 0.3523
# Epoch 26/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3569 - val_loss: 0.3125
# Epoch 27/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3800 - val_loss: 0.3190
# Epoch 28/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4036 - val_loss: 0.3483
# Epoch 29/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4055 - val_loss: 0.3520
# Epoch 30/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3966 - val_loss: 0.3598
# Epoch 31/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3698 - val_loss: 0.3618
# Epoch 32/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3621 - val_loss: 0.3598
# Epoch 33/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3634 - val_loss: 0.4017
# Epoch 34/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3887 - val_loss: 0.3118
# Epoch 35/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3726 - val_loss: 0.3191
# Epoch 36/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3729 - val_loss: 0.3141
# Epoch 37/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3530 - val_loss: 0.3360
# Epoch 38/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3665 - val_loss: 0.3484
# Epoch 39/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3470 - val_loss: 0.3053
# Epoch 40/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3645 - val_loss: 0.3380
# Epoch 41/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3531 - val_loss: 0.3093
# Epoch 42/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3484 - val_loss: 0.3270
# Epoch 43/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3525 - val_loss: 0.2984
# Epoch 44/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3398 - val_loss: 0.2954
# Epoch 45/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3252 - val_loss: 0.3019
# Epoch 46/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3460 - val_loss: 0.3613
# Epoch 47/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3772 - val_loss: 0.3280
# Epoch 48/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3659 - val_loss: 0.2856
# Epoch 49/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3584 - val_loss: 0.3061
# Epoch 50/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3334 - val_loss: 0.2934

# %%
y_test = y[index:]
y_pred = []
X_end = X[index]
while len(y_pred) < len(y_test):
  pred = model.predict(X_end.reshape(1, -1))[0,0]
  y_pred.append(pred)
  X_end = np.roll(X_end, -1)
  X_end[-1] = pred
plt.plot(y_test, label='y_test')
plt.plot(y_pred, label='y_pred')
plt.legend()

# %%
y_test_single = y[index:]
y_pred_single = []

i = index
while len(y_pred_single) < len(y_test_single):
  pred = model.predict(X[i].reshape(1,T, D))[0,0]
  i+=1
  y_pred_single.append(pred)

plt.plot(y_test_single, label='y_test_single')
plt.plot(y_pred_single, label='y_pred_singe')
plt.legend()

# %% [markdown]
# ## Trying the GlobalMaxPool1D

# %%
T = 40
D = 1
X = []
y = []
print(len(data))  
print("The last sample would be: " + str(len(data)) + " - " + str(T) + " = " + str((len(data)-T)) )

for i in range(len(data) - T):
  x = data[i:i+T]
  X.append(x)
  y_temp = data[i+T]
  y.append(y_temp)

X = np.array(X).reshape(-1, T, D) 
X = np.expand_dims(X, -1)
y = np.array(y)

i_layer = Input(shape = (T, D))
h_layer = LSTM(10, activation='tanh', return_sequences=True)(i_layer)
h_layer = GlobalMaxPool1D()(h_layer)
o_layer = Dense(1)(h_layer)
model = Model(i_layer, o_layer)
model.compile(loss = 'mse',
              optimizer = Adam(lr = 0.2))

index = -N//4
report = model.fit(X[:index], y[:index], epochs=50, validation_data=(X[index:], y[index:]))

plt.plot(report.history['loss'], label='training_loss')
plt.plot(report.history['val_loss'], label='validation_loss')
plt.legend()
# Out:
# 1000
# The last sample would be: 1000 - 40 = 960
# Epoch 1/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.8435 - val_loss: 0.4767
# Epoch 2/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4623 - val_loss: 0.4495
# Epoch 3/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4940 - val_loss: 0.5363
# Epoch 4/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5758 - val_loss: 0.4720
# Epoch 5/50
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3604 - val_loss: 0.3412
# Epoch 6/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3393 - val_loss: 0.3408
# Epoch 7/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3295 - val_loss: 0.3693
# Epoch 8/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3245 - val_loss: 0.3398
# Epoch 9/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3244 - val_loss: 0.3279
# Epoch 10/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3263 - val_loss: 0.3198
# Epoch 11/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3382 - val_loss: 0.3496
# Epoch 12/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3284 - val_loss: 0.3322
# Epoch 13/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3375 - val_loss: 0.3844
# Epoch 14/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3569 - val_loss: 0.4107
# Epoch 15/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3356 - val_loss: 0.3261
# Epoch 16/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3339 - val_loss: 0.3465
# Epoch 17/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3232 - val_loss: 0.4023
# Epoch 18/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3330 - val_loss: 0.3963
# Epoch 19/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3156 - val_loss: 0.4021
# Epoch 20/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3196 - val_loss: 0.3668
# Epoch 21/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3628 - val_loss: 0.4765
# Epoch 22/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3365 - val_loss: 0.3590
# Epoch 23/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3294 - val_loss: 0.3534
# Epoch 24/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3081 - val_loss: 0.3539
# Epoch 25/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3133 - val_loss: 0.3216
# Epoch 26/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3659 - val_loss: 0.3715
# Epoch 27/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3419 - val_loss: 0.3907
# Epoch 28/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3841 - val_loss: 0.4769
# Epoch 29/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4161 - val_loss: 0.4075
# Epoch 30/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4278 - val_loss: 0.4157
# Epoch 31/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3584 - val_loss: 0.3906
# Epoch 32/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3468 - val_loss: 0.3624
# Epoch 33/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3581 - val_loss: 0.4233
# Epoch 34/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3465 - val_loss: 0.3683
# Epoch 35/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3343 - val_loss: 0.4116
# Epoch 36/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3425 - val_loss: 0.4013
# Epoch 37/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3608 - val_loss: 0.4382
# Epoch 38/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3353 - val_loss: 0.3601
# Epoch 39/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3252 - val_loss: 0.3704
# Epoch 40/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3457 - val_loss: 0.3208
# Epoch 41/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3415 - val_loss: 0.3500
# Epoch 42/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3229 - val_loss: 0.3516
# Epoch 43/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3419 - val_loss: 0.3316
# Epoch 44/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3156 - val_loss: 0.3544
# Epoch 45/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3201 - val_loss: 0.3338
# Epoch 46/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3402 - val_loss: 0.3947
# Epoch 47/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3150 - val_loss: 0.3255
# Epoch 48/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3222 - val_loss: 0.3333
# Epoch 49/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3201 - val_loss: 0.3170
# Epoch 50/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3009 - val_loss: 0.3433

# %%
y_test = y[index:]
y_pred = []
X_end = X[index]
while len(y_pred) < len(y_test):
  pred = model.predict(X_end.reshape(1, -1))[0,0]
  y_pred.append(pred)
  X_end = np.roll(X_end, -1)
  X_end[-1] = pred
plt.plot(y_test, label='y_test')
plt.plot(y_pred, label='y_pred')
plt.legend()
plt.show()

y_test_single = y[index:]
y_pred_single = []

i = index
while len(y_pred_single) < len(y_test_single):
  pred = model.predict(X[i].reshape(1,T, D))[0,0]
  i+=1
  y_pred_single.append(pred)

plt.plot(y_test_single, label='y_test_single')
plt.plot(y_pred_single, label='y_pred_singe')
plt.legend()
plt.show()

# %%
T = 70
D = 1
X = []
y = []
print(len(data))  
print("The last sample would be: " + str(len(data)) + " - " + str(T) + " = " + str((len(data)-T)) )

for i in range(len(data) - T):
  x = data[i:i+T]
  X.append(x)
  y_temp = data[i+T]
  y.append(y_temp)

X = np.array(X).reshape(-1, T, D) 
y = np.array(y)

i_layer = Input(shape = (T, D))
h_layer = LSTM(10, activation='tanh', return_sequences=True)(i_layer)
h_layer = GlobalMaxPool1D()(h_layer)
o_layer = Dense(1)(h_layer)
model = Model(i_layer, o_layer)
model.compile(loss = 'mse',
              optimizer = Adam(lr = 0.2))

index = -N//4
report = model.fit(X[:index], y[:index], epochs=50, validation_data=(X[index:], y[index:]))

plt.plot(report.history['loss'], label='training_loss')
plt.plot(report.history['val_loss'], label='validation_loss')
plt.legend()
# Out:
# 1000
# The last sample would be: 1000 - 70 = 930
# Epoch 1/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.8999 - val_loss: 0.7713
# Epoch 2/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.7662 - val_loss: 0.7629
# Epoch 3/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.7585 - val_loss: 0.7376
# Epoch 4/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.7022 - val_loss: 0.4987
# Epoch 5/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6336 - val_loss: 0.7487
# Epoch 6/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.7713 - val_loss: 0.7464
# Epoch 7/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.7637 - val_loss: 0.7355
# Epoch 8/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.7034 - val_loss: 0.5664
# Epoch 9/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5660 - val_loss: 0.4895
# Epoch 10/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.4301 - val_loss: 0.3168
# Epoch 11/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3688 - val_loss: 0.2812
# Epoch 12/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3695 - val_loss: 0.3438
# Epoch 13/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3848 - val_loss: 0.2787
# Epoch 14/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3392 - val_loss: 0.2872
# Epoch 15/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3587 - val_loss: 0.2864
# Epoch 16/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3702 - val_loss: 0.2847
# Epoch 17/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3352 - val_loss: 0.2864
# Epoch 18/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3309 - val_loss: 0.2763
# Epoch 19/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3320 - val_loss: 0.2944
# Epoch 20/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3468 - val_loss: 0.2812
# Epoch 21/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3413 - val_loss: 0.2841
# Epoch 22/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3312 - val_loss: 0.2815
# Epoch 23/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3362 - val_loss: 0.2763
# Epoch 24/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3317 - val_loss: 0.2761
# Epoch 25/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3531 - val_loss: 0.2755
# Epoch 26/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3242 - val_loss: 0.2894
# Epoch 27/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3285 - val_loss: 0.2907
# Epoch 28/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3247 - val_loss: 0.2843
# Epoch 29/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3511 - val_loss: 0.3162
# Epoch 30/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3575 - val_loss: 0.2819
# Epoch 31/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3511 - val_loss: 0.2811
# Epoch 32/50
# 22/22 [==============================] - 0s 20ms/step - loss: 0.3333 - val_loss: 0.2925
# Epoch 33/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3425 - val_loss: 0.3000
# Epoch 34/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3229 - val_loss: 0.4020
# Epoch 35/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3440 - val_loss: 0.2871
# Epoch 36/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3812 - val_loss: 0.3024
# Epoch 37/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3401 - val_loss: 0.3069
# Epoch 38/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3240 - val_loss: 0.2841
# Epoch 39/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3098 - val_loss: 0.2797
# Epoch 40/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3433 - val_loss: 0.2874
# Epoch 41/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3489 - val_loss: 0.3151
# Epoch 42/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.4012 - val_loss: 0.3256
# Epoch 43/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3370 - val_loss: 0.2869
# Epoch 44/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3233 - val_loss: 0.2812
# Epoch 45/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3193 - val_loss: 0.3103
# Epoch 46/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3588 - val_loss: 0.2962
# Epoch 47/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3535 - val_loss: 0.3014
# Epoch 48/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3236 - val_loss: 0.2964
# Epoch 49/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3307 - val_loss: 0.3041
# Epoch 50/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3221 - val_loss: 0.3159

# %%
y_test = y[index:]
y_pred = []
X_end = X[index]
while len(y_pred) < len(y_test):
  pred = model.predict(X_end.reshape(1, -1))[0,0]
  y_pred.append(pred)
  X_end = np.roll(X_end, -1)
  X_end[-1] = pred
plt.plot(y_test, label='y_test')
plt.plot(y_pred, label='y_pred')
plt.legend()

# %%
y_test_single = y[index:]
y_pred_single = []

i = index
while len(y_pred_single) < len(y_test_single):
  pred = model.predict(X[i].reshape(1,T, D))[0,0]
  i+=1
  y_pred_single.append(pred)

plt.plot(y_test_single, label='y_test_single')
plt.plot(y_pred_single, label='y_pred_singe')
plt.legend()
